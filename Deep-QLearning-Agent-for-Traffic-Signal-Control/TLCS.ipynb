# %% [markdown]
# #####Setup

# %% [markdown]
# Set up the dependencies and install what is needed to make sumo and traci work

# %%
# set python 3.7
# !sudo apt-get update -y
# !sudo apt-get install python3.7
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1

# choose one of the given alternatives
# !sudo update-alternatives --config python3

# need to install pip
# !sudo apt install python3-pip

# clone repo
# !git clone "https://github.com/AndreaVidali/Deep-QLearning-Agent-for-Traffic-Signal-Control"
# !mv /content/Deep-QLearning-Agent-for-Traffic-Signal-Control/TLCS/* /content/
# !rm -r Deep-QLearning-Agent-for-Traffic-Signal-Control
# !ls -l

# needed to make pip work
# !sudo apt-get install python3.7-distutils

# required packages
# !pip install tensorflow==1.15
# !pip install ipykernel
# !pip install pydot
# !apt-get install graphviz
# !pip install h5py==2.10.0
# !pip install matplotlib

# install sumo and traci
# !add-apt-repository ppa:sumo/stable -y
# !apt-get update -y
# !apt-get install sumo sumo-tools sumo-doc
# !pip install traci

import os
os.environ['SUMO_HOME'] = "/usr/share/sumo/"

# !pip install protobuf==3.20.3
import os
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"

from IPython.display import clear_output
clear_output()

# !tensorflow --version
# !python --version
# Out:
# /bin/bash: line 1: tensorflow: command not found
# Python 3.11.11

# %%
# !python --version
# Out:
# Python 3.11.11

# %% [markdown]
# #####Training

# %% [markdown]
# We will train a model on 100 epochs

# %% [markdown]
# Running the training, change setting in training_setings.ini if you wish
#
# training with 100 epoch takes approximatley 2 hrs

# %%
# !python training_main.py # 100 epochs
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
#
# ----- Episode 1 of 100
#  Retrying in 1 seconds
# Simulating...
# Total reward: -26744.0 - Epsilon: 1.0
# Training...
# Simulation time: 9.5 s - Training time: 0.0 s - Total: 9.5 s
#
# ----- Episode 2 of 100
#  Retrying in 1 seconds
# Simulating...
# 2025-01-08 18:54:53.813117: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# Total reward: -29141.0 - Epsilon: 0.99
# Training...
# Simulation time: 9.3 s - Training time: 41.4 s - Total: 50.7 s
#
# ----- Episode 3 of 100
#  Retrying in 1 seconds
# Simulating...
# Total reward: -25764.0 - Epsilon: 0.98
# Training...
# ...

# %% [markdown]
# Training results on 100 epochs:

# %% [markdown]
# ![plot_reward.png](data:image/png;base64,...)![plot_queue.png](data:image/png;base64,...)

# %% [markdown]
# #####Testing

# %% [markdown]
# Running the testing, change settings in testing.ini
#
# **IMPORTANT**: for testing on colab set gui = False

# %% [markdown]
# Remember to set 'model_to_test' to 1 in testing_setting.ini

# %%
# !python testing_main.py # testing model_1 trained on 100 epochs
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...

# %% [markdown]
# Testing results:

# %% [markdown]
# ![plot_reward (1).png](data:image/png;base64,...)

# %% [markdown]
# ![plot_queue.png](data:image/png;base64,...)
